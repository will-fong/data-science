# %% [markdown]
# # Creating a Batch Inferencing Service
#
# In previous labs, you used an Azure ML *pipeline* to automate the training and registration of a model, and you published a model as a web service for real-time *inferencing* (getting predictions from a model). Now you'll combine these two concepts to create a pipeline for *batch inferencing*. What does that mean? Well, imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. That's what you'll implement in this exercise.
#
# ## Before You Start
#
# Before you start this lab, ensure that you have completed the *Create an Azure Machine Learning Workspace* and *Create a Compute Instance* tasks in [Lab 1: Getting Started with Azure Machine Learning](./labdocs/Lab01.md). Then open this notebook in Jupyter on your Compute Instance.
#
# Let's start by ensuring that you have the latest version of the Azure ML SDK installed.

# %%
# !pip install --upgrade azureml-sdk[notebooks,automl,explain]
# Out:
# Requirement already up-to-date: azureml-sdk[automl,explain,notebooks] in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-train~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-core~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-pipeline~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-train-automl-client~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-dataprep[fuse]<1.7.0a,>=1.6.2a in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.6.3)
# Requirement already satisfied, skipping upgrade: azureml-train-automl~=1.6.0; extra == "automl" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-explain-model~=1.6.0; extra == "explain" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-contrib-notebook~=1.6.0; extra == "notebooks" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-widgets~=1.6.0; extra == "notebooks" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-train-core~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.6.0.post1)
# Requirement already satisfied, skipping upgrade: msrest>=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.6.14)
# Requirement already satisfied, skipping upgrade: SecretStorage in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (3.1.2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-resource>=1.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (9.0.0)
# Requirement already satisfied, skipping upgrade: requests>=2.19.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (2.23.0)
# Requirement already satisfied, skipping upgrade: contextlib2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.6.0.post1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-network~=10.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (10.2.0)
# Requirement already satisfied, skipping upgrade: urllib3>=1.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.25.9)
# Requirement already satisfied, skipping upgrade: docker in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (4.2.0)
# Requirement already satisfied, skipping upgrade: azure-graphrbac>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.61.1)
# Requirement already satisfied, skipping upgrade: ruamel.yaml>0.16.7 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.16.10)
# Requirement already satisfied, skipping upgrade: azure-common>=1.1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.1.25)
# Requirement already satisfied, skipping upgrade: azure-mgmt-keyvault>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (2.2.0)
# Requirement already satisfied, skipping upgrade: msrestazure>=0.4.33 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.6.3)
# Requirement already satisfied, skipping upgrade: backports.tempfile in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerregistry>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (2.8.0)
# Requirement already satisfied, skipping upgrade: adal>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.2.3)
# Requirement already satisfied, skipping upgrade: jmespath in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.10.0)
# Requirement already satisfied, skipping upgrade: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (2.9.2)
# Requirement already satisfied, skipping upgrade: ndg-httpsclient in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.5.1)
# Requirement already satisfied, skipping upgrade: PyJWT in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.7.1)
# Requirement already satisfied, skipping upgrade: jsonpickle in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.4.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-authorization>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.60.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (2.8.1)
# Requirement already satisfied, skipping upgrade: pathspec in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.8.0)
# Requirement already satisfied, skipping upgrade: pytz in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (2019.3)
# Requirement already satisfied, skipping upgrade: pyopenssl in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (19.1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-storage>=1.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (10.0.0)
# Requirement already satisfied, skipping upgrade: azureml-pipeline-core~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-pipeline~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-pipeline-steps~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-pipeline~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-telemetry~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-client~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-automl-core~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-client~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-dataprep-native<15.0.0,>=14.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.7.0a,>=1.6.2a->azureml-sdk[automl,explain,notebooks]) (14.1.0)
# Requirement already satisfied, skipping upgrade: cloudpickle>=1.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.7.0a,>=1.6.2a->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied, skipping upgrade: dotnetcore2>=2.1.14 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.7.0a,>=1.6.2a->azureml-sdk[automl,explain,notebooks]) (2.1.14)
# Requirement already satisfied, skipping upgrade: azure-identity<1.3.0,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.7.0a,>=1.6.2a->azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Requirement already satisfied, skipping upgrade: fusepy>=3.0.1; extra == "fuse" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.7.0a,>=1.6.2a->azureml-sdk[automl,explain,notebooks]) (3.0.1)
# Requirement already satisfied, skipping upgrade: azureml-automl-runtime~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.6.0.post1)
# Requirement already satisfied, skipping upgrade: azureml-train-automl-runtime~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-interpret~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-explain-model~=1.6.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: ipython in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.14.0)
# Requirement already satisfied, skipping upgrade: ipykernel in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.3.0)
# Requirement already satisfied, skipping upgrade: papermill<2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.2.1)
# Requirement already satisfied, skipping upgrade: ipywidgets>=7.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-widgets~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.5.1)
# Requirement already satisfied, skipping upgrade: flake8<=3.7.9,>=3.1.0; python_version >= "3.6" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-core~=1.6.0->azureml-train~=1.6.0->azureml-sdk[automl,explain,notebooks]) (3.7.9)
# Requirement already satisfied, skipping upgrade: azureml-train-restclients-hyperdrive~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-core~=1.6.0->azureml-train~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied, skipping upgrade: isodate>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.6.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: jeepney>=0.4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from SecretStorage->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.4.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (2.9)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (3.0.4)
# Requirement already satisfied, skipping upgrade: six>=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.12.0)
# Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.57.0)
# Requirement already satisfied, skipping upgrade: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ruamel.yaml>0.16.7->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.2.0)
# Requirement already satisfied, skipping upgrade: backports.weakref in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.0.post1)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.14.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ndg-httpsclient->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.4.8)
# Requirement already satisfied, skipping upgrade: importlib-metadata in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonpickle->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: applicationinsights in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-telemetry~=1.6.0->azureml-train-automl-client~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.11.9)
# Requirement already satisfied, skipping upgrade: distro>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dotnetcore2>=2.1.14->azureml-dataprep[fuse]<1.7.0a,>=1.6.2a->azureml-sdk[automl,explain,notebooks]) (1.5.0)
# Requirement already satisfied, skipping upgrade: azure-core<2.0.0,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep[fuse]<1.7.0a,>=1.6.2a->azureml-sdk[automl,explain,notebooks]) (1.5.0)
# Requirement already satisfied, skipping upgrade: msal<2.0.0,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep[fuse]<1.7.0a,>=1.6.2a->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied, skipping upgrade: msal-extensions~=0.1.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep[fuse]<1.7.0a,>=1.6.2a->azureml-sdk[automl,explain,notebooks]) (0.1.3)
# Requirement already satisfied, skipping upgrade: onnxruntime==1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.0.0)
# Requirement already satisfied, skipping upgrade: py-cpuinfo in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (5.0.0)
# Requirement already satisfied, skipping upgrade: statsmodels<=0.10.2,>=0.9.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.10.2)
# Requirement already satisfied, skipping upgrade: onnxmltools==1.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.4.1)
# Requirement already satisfied, skipping upgrade: lightgbm<=2.3.0,>=2.0.11 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.3.0)
# Requirement already satisfied, skipping upgrade: scipy<=1.4.1,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.4.1)
# Requirement already satisfied, skipping upgrade: onnx<=1.6.0,>=1.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: sklearn-pandas<=1.7.0,>=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.7.0)
# Requirement already satisfied, skipping upgrade: pmdarima==1.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.1.1)
# Requirement already satisfied, skipping upgrade: smart-open<=1.9.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.9.0)
# Requirement already satisfied, skipping upgrade: onnxconverter-common<=1.6.0,>=1.4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: patsy>=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.5.1)
# Requirement already satisfied, skipping upgrade: gensim in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (3.8.3)
# Requirement already satisfied, skipping upgrade: nimbusml>=1.7.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.7.1)
# Requirement already satisfied, skipping upgrade: dill>=0.2.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.3.1.1)
# Requirement already satisfied, skipping upgrade: joblib==0.14.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.14.1)
# Requirement already satisfied, skipping upgrade: resource>=0.1.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.2.1)
# Requirement already satisfied, skipping upgrade: skl2onnx==1.4.9 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.4.9)
# Requirement already satisfied, skipping upgrade: scikit-learn<=0.20.3,>=0.19.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.20.3)
# Requirement already satisfied, skipping upgrade: pandas<=0.23.4,>=0.21.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.23.4)
# Requirement already satisfied, skipping upgrade: psutil<6.0.0,>=5.2.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (5.7.0)
# Requirement already satisfied, skipping upgrade: numpy<=1.16.2,>=1.16.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.16.2)
# Requirement already satisfied, skipping upgrade: azureml-defaults~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied, skipping upgrade: interpret-community==0.10.* in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-interpret~=1.6.0->azureml-explain-model~=1.6.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (0.10.2)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.7.0)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (2.0.10)
# Requirement already satisfied, skipping upgrade: pygments in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (2.6.1)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.15.1)
# Requirement already satisfied, skipping upgrade: backcall in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.1.0)
# Requirement already satisfied, skipping upgrade: pickleshare in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.7.5)
# Requirement already satisfied, skipping upgrade: decorator in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.4.2)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (46.4.0.post20200518)
# Requirement already satisfied, skipping upgrade: traitlets>=4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.3.3)
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (6.0.4)
# Requirement already satisfied, skipping upgrade: jupyter-client in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (6.1.3)
# Requirement already satisfied, skipping upgrade: nbconvert>=5.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.6.1)
# Requirement already satisfied, skipping upgrade: ansiwrap in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.8.4)
# Requirement already satisfied, skipping upgrade: nbformat in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.0.6)
# Requirement already satisfied, skipping upgrade: future in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.18.2)
# Requirement already satisfied, skipping upgrade: tenacity in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (6.2.0)
# Requirement already satisfied, skipping upgrade: click in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.1.2)
# Requirement already satisfied, skipping upgrade: entrypoints in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.3)
# Requirement already satisfied, skipping upgrade: pyyaml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.1.2)
# Requirement already satisfied, skipping upgrade: tqdm>=4.32.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.46.0)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml-widgets~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (3.5.1)
# Requirement already satisfied, skipping upgrade: mccabe<0.7.0,>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=1.6.0->azureml-train~=1.6.0->azureml-sdk[automl,explain,notebooks]) (0.6.1)
# Requirement already satisfied, skipping upgrade: pyflakes<2.2.0,>=2.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=1.6.0->azureml-train~=1.6.0->azureml-sdk[automl,explain,notebooks]) (2.1.1)
# Requirement already satisfied, skipping upgrade: pycodestyle<2.6.0,>=2.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=1.6.0->azureml-train~=1.6.0->azureml-sdk[automl,explain,notebooks]) (2.5.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (3.1.0)
# Requirement already satisfied, skipping upgrade: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (2.20)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata->jsonpickle->azureml-core~=1.6.0->azureml-sdk[automl,explain,notebooks]) (3.1.0)
# Requirement already satisfied, skipping upgrade: portalocker~=1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msal-extensions~=0.1.3->azure-identity<1.3.0,>=1.2.0->azureml-dataprep[fuse]<1.7.0a,>=1.6.2a->azureml-sdk[automl,explain,notebooks]) (1.7.0)
# Requirement already satisfied, skipping upgrade: keras2onnx in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from onnxmltools==1.4.1->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.6.1)
# Requirement already satisfied, skipping upgrade: protobuf in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from onnxmltools==1.4.1->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (3.12.1)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from onnx<=1.6.0,>=1.5.0->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (3.7.4.2)
# Requirement already satisfied, skipping upgrade: Cython>=0.29 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pmdarima==1.1.1->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.29.14)
# Requirement already satisfied, skipping upgrade: boto>=2.32 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from smart-open<=1.9.0->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.49.0)
# Requirement already satisfied, skipping upgrade: boto3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from smart-open<=1.9.0->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.13.17)
# Requirement already satisfied, skipping upgrade: JsonForm>=0.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from resource>=0.1.8->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.0.2)
# Requirement already satisfied, skipping upgrade: python-easyconfig>=0.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from resource>=0.1.8->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.1.7)
# Requirement already satisfied, skipping upgrade: JsonSir>=0.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from resource>=0.1.8->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.0.2)
# Requirement already satisfied, skipping upgrade: werkzeug==0.16.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.6.0->azureml-train-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.16.1)
# Requirement already satisfied, skipping upgrade: flask==1.0.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.6.0->azureml-train-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.0.3)
# Requirement already satisfied, skipping upgrade: gunicorn==19.9.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.6.0->azureml-train-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (19.9.0)
# Requirement already satisfied, skipping upgrade: azureml-model-management-sdk==1.0.1b6.post1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.6.0->azureml-train-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.0.1b6.post1)
# Requirement already satisfied, skipping upgrade: json-logging-py==0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.6.0->azureml-train-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.2)
# Requirement already satisfied, skipping upgrade: configparser==3.7.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-defaults~=1.6.0->azureml-train-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (3.7.4)
# Requirement already satisfied, skipping upgrade: interpret-core[required]<=0.1.21,>=0.1.20 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from interpret-community==0.10.*->azureml-interpret~=1.6.0->azureml-explain-model~=1.6.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (0.1.21)
# Requirement already satisfied, skipping upgrade: shap<=0.34.0,>=0.20.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from interpret-community==0.10.*->azureml-interpret~=1.6.0->azureml-explain-model~=1.6.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (0.34.0)
# Requirement already satisfied, skipping upgrade: packaging in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from interpret-community==0.10.*->azureml-interpret~=1.6.0->azureml-explain-model~=1.6.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (20.4)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.6.0)
# Requirement already satisfied, skipping upgrade: wcwidth in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.1.9)
# Requirement already satisfied, skipping upgrade: parso>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jedi>=0.10->ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.7.0)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from traitlets>=4.2->ipython->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.2.0)
# Requirement already satisfied, skipping upgrade: pyzmq>=13 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jupyter-client->ipykernel->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (19.0.1)
# Requirement already satisfied, skipping upgrade: jupyter-core>=4.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jupyter-client->ipykernel->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.6.3)
# Requirement already satisfied, skipping upgrade: bleach in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (3.1.5)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.4.2)
# Requirement already satisfied, skipping upgrade: defusedxml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.6.0)
# Requirement already satisfied, skipping upgrade: testpath in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.4.4)
# Requirement already satisfied, skipping upgrade: jinja2>=2.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (2.11.2)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.8.4)
# Requirement already satisfied, skipping upgrade: textwrap3>=0.9.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ansiwrap->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.9.2)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbformat->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (3.2.0)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (6.0.3)
# Requirement already satisfied, skipping upgrade: fire in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from keras2onnx->onnxmltools==1.4.1->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.3.1)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from boto3->smart-open<=1.9.0->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.3.3)
# Requirement already satisfied, skipping upgrade: botocore<1.17.0,>=1.16.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from boto3->smart-open<=1.9.0->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.16.17)
# Requirement already satisfied, skipping upgrade: itsdangerous>=0.24 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from flask==1.0.3->azureml-defaults~=1.6.0->azureml-train-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.1.0)
# Requirement already satisfied, skipping upgrade: liac-arff>=2.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.6.0->azureml-train-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (2.4.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from packaging->interpret-community==0.10.*->azureml-interpret~=1.6.0->azureml-explain-model~=1.6.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (2.4.7)
# Requirement already satisfied, skipping upgrade: webencodings in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from bleach->nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.5.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jinja2>=2.4->nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.1.1)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.16.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->papermill<2->azureml-contrib-notebook~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (19.3.0)
# Requirement already satisfied, skipping upgrade: Send2Trash in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.5.0)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.8.2)
# Requirement already satisfied, skipping upgrade: prometheus-client in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.6.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.8.0)
# Requirement already satisfied, skipping upgrade: termcolor in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from fire->keras2onnx->onnxmltools==1.4.1->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.1.0)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from botocore<1.17.0,>=1.16.17->boto3->smart-open<=1.9.0->azureml-automl-runtime~=1.6.0->azureml-train-automl~=1.6.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.15.2)

# %% [markdown]
# ## Connect to Your Workspace
#
# Now connect to your workspace using the Azure ML SDK.
#
# > **Note**: You may be prompted to authenticate. Just copy the code and click the link provided to sign into your Azure subscription, and then return to this notebook.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code FAPY5RVW3 to authenticate.
# Interactive authentication successfully completed.
# Ready to use Azure ML 1.6.0 to work with wfml

# %% [markdown]
# ## Train and Register a Model
#
# Now run the cell below to train and register a model.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace = ws, name = "diabetes-training")
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: diabetes-training
# Loading Data...
# Training a decision tree model
# Accuracy: 0.889
# AUC: 0.8756181899596994
# Model trained and registered.

# %% [markdown]
# ## Generate and Upload Batch Data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this course, you'll generate a random sample from our diabetes CSV file and use those to test the pipeline. Then you'll upload that data to a datastore in the Azure Machine Learning workspace and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploading batch-data/10.csv
# Uploading batch-data/100.csv
# Uploading batch-data/11.csv
# Uploading batch-data/12.csv
# Uploading batch-data/13.csv
# Uploading batch-data/14.csv
# Uploading batch-data/15.csv
# Uploading batch-data/16.csv
# Uploading batch-data/17.csv
# Uploading batch-data/18.csv
# Uploading batch-data/19.csv
# Uploading batch-data/2.csv
# Uploading batch-data/20.csv
# Uploading batch-data/21.csv
# Uploading batch-data/22.csv
# Uploading batch-data/23.csv
# Uploading batch-data/24.csv
# Uploading batch-data/25.csv
# Uploading batch-data/26.csv
# Uploading batch-data/27.csv
# Uploading batch-data/28.csv
# Uploading batch-data/29.csv
# Uploading batch-data/3.csv
# Uploading batch-data/30.csv
# Uploading batch-data/31.csv
# Uploading batch-data/32.csv
# Uploading batch-data/33.csv
# Uploading batch-data/34.csv
# Uploading batch-data/35.csv
# Uploading batch-data/36.csv
# Uploading batch-data/37.csv
# Uploaded batch-data/14.csv, 1 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 2 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/22.csv, 3 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/39.csv, 4 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/4.csv, 5 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/40.csv, 6 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/41.csv, 7 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/42.csv, 8 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/43.csv, 9 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/44.csv, 10 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/45.csv, 11 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/35.csv, 12 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/32.csv, 13 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/46.csv, 14 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/47.csv, 15 files out of an estimated total of 100
# Uploaded batch-data/48.csv, 16 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploading batch-data/51.csv
# Uploaded batch-data/10.csv, 17 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/1.csv, 18 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/49.csv, 19 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/5.csv, 20 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/51.csv, 21 files out of an estimated total of 100
# Uploaded batch-data/50.csv, 22 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploading batch-data/57.csv
# Uploaded batch-data/54.csv, 23 files out of an estimated total of 100
# Uploaded batch-data/53.csv, 24 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploading batch-data/59.csv
# Uploaded batch-data/52.csv, 25 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/55.csv, 26 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/57.csv, 27 files out of an estimated total of 100
# Uploaded batch-data/56.csv, 28 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploading batch-data/62.csv
# Uploaded batch-data/60.csv, 29 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/6.csv, 30 files out of an estimated total of 100
# Uploaded batch-data/59.csv, 31 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploading batch-data/65.csv
# Uploaded batch-data/58.csv, 32 files out of an estimated total of 100
# Uploaded batch-data/62.csv, 33 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploading batch-data/67.csv
# Uploaded batch-data/61.csv, 34 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/64.csv, 35 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/65.csv, 36 files out of an estimated total of 100
# Uploaded batch-data/63.csv, 37 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploading batch-data/70.csv
# Uploaded batch-data/66.csv, 38 files out of an estimated total of 100
# Uploaded batch-data/68.csv, 39 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/67.csv, 40 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/19.csv, 41 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploading batch-data/74.csv
# Uploaded batch-data/7.csv, 42 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/69.csv, 43 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/71.csv, 44 files out of an estimated total of 100
# Uploaded batch-data/20.csv, 45 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploading batch-data/78.csv
# Uploaded batch-data/70.csv, 46 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/75.csv, 47 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/3.csv, 48 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/25.csv, 49 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/15.csv, 50 files out of an estimated total of 100
# Uploaded batch-data/74.csv, 51 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/8.csv, 52 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/17.csv, 53 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploading batch-data/85.csv
# Uploaded batch-data/11.csv, 54 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/79.csv, 55 files out of an estimated total of 100
# Uploaded batch-data/23.csv, 56 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploading batch-data/88.csv
# Uploaded batch-data/76.csv, 57 files out of an estimated total of 100
# Uploaded batch-data/81.csv, 58 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/73.csv, 59 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/36.csv, 60 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/21.csv, 61 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/28.csv, 62 files out of an estimated total of 100
# Uploaded batch-data/77.csv, 63 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/84.csv, 64 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploading batch-data/94.csv
# Uploaded batch-data/80.csv, 65 files out of an estimated total of 100
# Uploaded batch-data/78.csv, 66 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/82.csv, 67 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/26.csv, 68 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploading batch-data/98.csv
# Uploaded batch-data/16.csv, 69 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/31.csv, 70 files out of an estimated total of 100
# Uploaded batch-data/83.csv, 71 files out of an estimated total of 100
# Uploaded batch-data/90.csv, 72 files out of an estimated total of 100
# Uploaded batch-data/13.csv, 73 files out of an estimated total of 100
# Uploaded batch-data/72.csv, 74 files out of an estimated total of 100
# Uploaded batch-data/95.csv, 75 files out of an estimated total of 100
# Uploaded batch-data/100.csv, 76 files out of an estimated total of 100
# Uploaded batch-data/37.csv, 77 files out of an estimated total of 100
# Uploaded batch-data/89.csv, 78 files out of an estimated total of 100
# Uploaded batch-data/87.csv, 79 files out of an estimated total of 100
# Uploaded batch-data/12.csv, 80 files out of an estimated total of 100
# Uploaded batch-data/85.csv, 81 files out of an estimated total of 100
# Uploaded batch-data/91.csv, 82 files out of an estimated total of 100
# Uploaded batch-data/86.csv, 83 files out of an estimated total of 100
# Uploaded batch-data/92.csv, 84 files out of an estimated total of 100
# Uploaded batch-data/18.csv, 85 files out of an estimated total of 100
# Uploaded batch-data/30.csv, 86 files out of an estimated total of 100
# Uploaded batch-data/88.csv, 87 files out of an estimated total of 100
# Uploaded batch-data/34.csv, 88 files out of an estimated total of 100
# Uploaded batch-data/97.csv, 89 files out of an estimated total of 100
# Uploaded batch-data/24.csv, 90 files out of an estimated total of 100
# Uploaded batch-data/99.csv, 91 files out of an estimated total of 100
# Uploaded batch-data/96.csv, 92 files out of an estimated total of 100
# Uploaded batch-data/33.csv, 93 files out of an estimated total of 100
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploaded batch-data/98.csv, 95 files out of an estimated total of 100
# Uploaded batch-data/94.csv, 96 files out of an estimated total of 100
# Uploaded batch-data/9.csv, 97 files out of an estimated total of 100
# Uploaded batch-data/29.csv, 98 files out of an estimated total of 100
# Uploaded batch-data/2.csv, 99 files out of an estimated total of 100
# Uploaded batch-data/27.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f5b35a65747f> in <module>
#      31                                              name='batch-data',
#      32                                              description='batch data',
# ---> 33                                              create_new_version=True)
#      34 except Exception as ex:
#      35     print(ex)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/data/_loggerfactory.py in wrapper(*args, **kwargs)
#     104             with _LoggerFactory.track_activity(logger, func.__name__, activity_type, custom_dimensions) as al:
#     105                 try:
# --> 106                     return func(*args, **kwargs)
#     107                 except Exception as e:
#     108                     if hasattr(al, 'activity_info') and hasattr(e, 'error_code'):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/data/abstract_dataset.py in register(self, workspace, name, description, tags, create_new_version)
#     309                     ).format(existing_name, existing_version))
#     310
# --> 311         success, result = _make_request(request, handle_error)
#     312         if not success:
#     313             raise result
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/data/_dataset_rest_helper.py in _make_request(request_fn, handle_error_fn)
#     164
#     165     try:
# --> 166         return (True, request_fn())
#     167     except HttpOperationError as error:
#     168         try:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/data/abstract_dataset.py in request()
#     288                 if_exists_ok=create_new_version,
#     289                 update_definition_if_exists=create_new_version,
# --> 290                 custom_headers=self._get_telemetry_headers())
#     291
#     292         def handle_error(error):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/operations/dataset_operations.py in register(self, subscription_id, resource_group_name, workspace_name, dataset_dto, register_as_pending, if_exists_ok, update_definition_if_exists, with_data_hash, custom_headers, raw, **operation_config)
#    1801         request = self._client.post(url, query_parameters)
#    1802         response = self._client.send(
# -> 1803             request, header_parameters, body_content, stream=False, **operation_config)
#    1804
#    1805         if response.status_code not in [200]:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/msrest/service_client.py in send(self, request, headers, content, **kwargs)
#     334         kwargs.setdefault('stream', True)
#     335         try:
# --> 336             pipeline_response = self.config.pipeline.run(request, **kwargs)
#     337             # There is too much thing that expects this method to return a "requests.Response"
#     338             # to break it in a compatible release.
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/msrest/pipeline/__init__.py in run(self, request, **kwargs)
#     195         pipeline_request = Request(request, context)  # type: Request[HTTPRequestType]
#     196         first_node = self._impl_policies[0] if self._impl_policies else self._sender
# --> 197         return first_node.send(pipeline_request, **kwargs)  # type: ignore
#     198
#     199 class HTTPSender(AbstractContextManager, ABC, Generic[HTTPRequestType, HTTPResponseType]):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/msrest/pipeline/__init__.py in send(self, request, **kwargs)
#     148         self._policy.on_request(request, **kwargs)
#     149         try:
# --> 150             response = self.next.send(request, **kwargs)
#     151         except Exception:
#     152             if not self._policy.on_exception(request, **kwargs):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/msrest/pipeline/requests.py in send(self, request, **kwargs)
#      70         try:
#      71             try:
# ---> 72                 return self.next.send(request, **kwargs)
#      73             except (oauth2.rfc6749.errors.InvalidGrantError,
#      74                     oauth2.rfc6749.errors.TokenExpiredError) as err:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/msrest/pipeline/requests.py in send(self, request, **kwargs)
#     135
#     136         try:
# --> 137             return self.next.send(request, **kwargs)
#     138         finally:
#     139             if old_max_redirects:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/msrest/pipeline/__init__.py in send(self, request, **kwargs)
#     148         self._policy.on_request(request, **kwargs)
#     149         try:
# --> 150             response = self.next.send(request, **kwargs)
#     151         except Exception:
#     152             if not self._policy.on_exception(request, **kwargs):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/msrest/pipeline/requests.py in send(self, request, **kwargs)
#     191         return Response(
#     192             request,
# --> 193             self.driver.send(request.http_request, **kwargs)
#     194         )
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/msrest/universal_http/requests.py in send(self, request, **kwargs)
#     331         """
#     332         requests_kwargs = self._configure_send(request, **kwargs)
# --> 333         return super(RequestsHTTPSender, self).send(request, **requests_kwargs)
#     334
#     335
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/msrest/universal_http/requests.py in send(self, request, **kwargs)
#     140                 request.method,
#     141                 request.url,
# --> 142                 **kwargs)
#     143         except requests.RequestException as err:
#     144             msg = "Error occurred in request."
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /anaconda/envs/azureml_py36/lib/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /anaconda/envs/azureml_py36/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /anaconda/envs/azureml_py36/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /anaconda/envs/azureml_py36/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create Compute
#
# We'll need a compute context for the pipeline, so we'll create an Azure Machine Learning compute cluster in your workspace (or use an existing one if you have created it previously).
#
# > **Important**: Change *your-compute-cluster* to the unique name for your compute cluster in the code below before running it!

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "wfml-cluster"

# Check for existing cluster
try:
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # Create an AzureMl Compute resource
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS2_V2', max_nodes=2)
    inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)

inference_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Create a Pipeline for Batch Inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_diabetes.py

# %% [markdown]
# Next we'll define a run context that includes the dependencies required by the script

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.core.runconfig import CondaDependencies

# Add dependencies required by the model
# For scikit-learn models, you need scikit-learn
cd = CondaDependencies.create(pip_packages=['scikit-learn'])

batch_env = Environment(name='batch_environment')
batch_env.python.conda_dependencies = cd
batch_env.docker.enabled = True
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.
#
# So you'll need to install the library containing the **ParallelRunStep** class.

# %%
# !pip install --upgrade azureml-contrib-pipeline-steps
# Out:
# Requirement already up-to-date: azureml-contrib-pipeline-steps in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-dataprep<1.7.0a,>=1.6.2a in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-pipeline-steps) (1.6.3)
# Requirement already satisfied, skipping upgrade: azureml-pipeline-core~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-pipeline-steps) (1.6.0)
# Requirement already satisfied, skipping upgrade: azureml-core~=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-pipeline-steps) (1.6.0)
# Requirement already satisfied, skipping upgrade: cloudpickle>=1.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<1.7.0a,>=1.6.2a->azureml-contrib-pipeline-steps) (1.3.0)
# Requirement already satisfied, skipping upgrade: azureml-dataprep-native<15.0.0,>=14.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<1.7.0a,>=1.6.2a->azureml-contrib-pipeline-steps) (14.1.0)
# Requirement already satisfied, skipping upgrade: dotnetcore2>=2.1.14 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<1.7.0a,>=1.6.2a->azureml-contrib-pipeline-steps) (2.1.14)
# Requirement already satisfied, skipping upgrade: azure-identity<1.3.0,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<1.7.0a,>=1.6.2a->azureml-contrib-pipeline-steps) (1.2.0)
# Requirement already satisfied, skipping upgrade: msrestazure>=0.4.33 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.6.3)
# Requirement already satisfied, skipping upgrade: jmespath in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.10.0)
# Requirement already satisfied, skipping upgrade: adal>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (1.2.3)
# Requirement already satisfied, skipping upgrade: requests>=2.19.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (2.23.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-storage>=1.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (10.0.0)
# Requirement already satisfied, skipping upgrade: pyopenssl in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (19.1.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (2.8.1)
# Requirement already satisfied, skipping upgrade: PyJWT in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (1.7.1)
# Requirement already satisfied, skipping upgrade: SecretStorage in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (3.1.2)
# Requirement already satisfied, skipping upgrade: jsonpickle in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (1.4.1)
# Requirement already satisfied, skipping upgrade: ndg-httpsclient in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.5.1)
# Requirement already satisfied, skipping upgrade: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (2.9.2)
# Requirement already satisfied, skipping upgrade: ruamel.yaml>0.16.7 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.16.10)
# Requirement already satisfied, skipping upgrade: backports.tempfile in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-keyvault>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (2.2.0)
# Requirement already satisfied, skipping upgrade: pathspec in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.8.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-authorization>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.60.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-network~=10.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (10.2.0)
# Requirement already satisfied, skipping upgrade: azure-graphrbac>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.61.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerregistry>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (2.8.0)
# Requirement already satisfied, skipping upgrade: pytz in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (2019.3)
# Requirement already satisfied, skipping upgrade: urllib3>=1.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (1.25.9)
# Requirement already satisfied, skipping upgrade: msrest>=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.6.14)
# Requirement already satisfied, skipping upgrade: azure-common>=1.1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (1.1.25)
# Requirement already satisfied, skipping upgrade: azure-mgmt-resource>=1.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (9.0.0)
# Requirement already satisfied, skipping upgrade: contextlib2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.6.0.post1)
# Requirement already satisfied, skipping upgrade: docker in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (4.2.0)
# Requirement already satisfied, skipping upgrade: distro>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dotnetcore2>=2.1.14->azureml-dataprep<1.7.0a,>=1.6.2a->azureml-contrib-pipeline-steps) (1.5.0)
# Requirement already satisfied, skipping upgrade: six>=1.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep<1.7.0a,>=1.6.2a->azureml-contrib-pipeline-steps) (1.12.0)
# Requirement already satisfied, skipping upgrade: azure-core<2.0.0,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep<1.7.0a,>=1.6.2a->azureml-contrib-pipeline-steps) (1.5.0)
# Requirement already satisfied, skipping upgrade: msal-extensions~=0.1.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep<1.7.0a,>=1.6.2a->azureml-contrib-pipeline-steps) (0.1.3)
# Requirement already satisfied, skipping upgrade: msal<2.0.0,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep<1.7.0a,>=1.6.2a->azureml-contrib-pipeline-steps) (1.3.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (2.9)
# Requirement already satisfied, skipping upgrade: jeepney>=0.4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from SecretStorage->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.4.3)
# Requirement already satisfied, skipping upgrade: importlib-metadata in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonpickle->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (1.6.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ndg-httpsclient->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.4.8)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (1.14.0)
# Requirement already satisfied, skipping upgrade: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ruamel.yaml>0.16.7->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.2.0)
# Requirement already satisfied, skipping upgrade: backports.weakref in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (1.0.post1)
# Requirement already satisfied, skipping upgrade: isodate>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.6.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (1.3.0)
# Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (0.57.0)
# Requirement already satisfied, skipping upgrade: portalocker~=1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msal-extensions~=0.1.3->azure-identity<1.3.0,>=1.2.0->azureml-dataprep<1.7.0a,>=1.6.2a->azureml-contrib-pipeline-steps) (1.7.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata->jsonpickle->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (3.1.0)
# Requirement already satisfied, skipping upgrade: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (2.20)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core~=1.6.0->azureml-contrib-pipeline-steps) (3.1.0)

# %% [markdown]
# OK, now you're ready to define a **ParallelRunStep** pipeline step.

# %%
from azureml.contrib.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.pipeline.core import PipelineData

default_ds = ws.get_default_datastore()
model = ws.models['diabetes_model']

output_dir = PipelineData(name='inferences', 
                          datastore=default_ds, 
                          output_path_on_compute='diabetes/results')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    models=[model],
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'batch_prediction_pipeline').submit(pipeline)
print('Running pipeline...')
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [30c92776][25ea159f-93a2-43dc-bb62-58be6375b5b3], (This step will run and generate new outputs)
# Created data reference diabetes_batch_0 for StepId [31e44073][14b177c4-d5fc-4570-b965-ffc9de5fc02e], (Consumers of this data will generate new runs.)
# Submitted PipelineRun 4f0a0490-92fc-451e-816b-815dcc954ec8
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_prediction_pipeline/runs/4f0a0490-92fc-451e-816b-815dcc954ec8?wsid=/subscriptions/db63e310-2279-4738-a96f-52d65ba09d6a/resourcegroups/learn-bcccf658-bb50-4d7b-962a-65e7bcc6af75/workspaces/wfml
# Running pipeline...
# PipelineRunId: 4f0a0490-92fc-451e-816b-815dcc954ec8
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_prediction_pipeline/runs/4f0a0490-92fc-451e-816b-815dcc954ec8?wsid=/subscriptions/db63e310-2279-4738-a96f-52d65ba09d6a/resourcegroups/learn-bcccf658-bb50-4d7b-962a-65e7bcc6af75/workspaces/wfml
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 681e2f9e-0a67-4731-bd6b-735c17963b3b
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_prediction_pipeline/runs/681e2f9e-0a67-4731-bd6b-735c17963b3b?wsid=/subscriptions/db63e310-2279-4738-a96f-52d65ba09d6a/resourcegroups/learn-bcccf658-bb50-4d7b-962a-65e7bcc6af75/workspaces/wfml
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2020/06/06 22:27:36 Downloading source code...
# 2020/06/06 22:27:37 Finished downloading source code
# 2020/06/06 22:27:38 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/06/06 22:27:38 Successfully set up Docker network: acb_default_network
# 2020/06/06 22:27:38 Setting up Docker configuration...
# 2020/06/06 22:27:39 Successfully set up Docker configuration
# 2020/06/06 22:27:39 Logging in to registry: wfml470d4c29.azurecr.io
# 2020/06/06 22:27:40 Successfully logged into wfml470d4c29.azurecr.io
# 2020/06/06 22:27:40 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/06/06 22:27:40 Scanning for dependencies...
# 2020/06/06 22:27:41 Successfully scanned dependencies
# 2020/06/06 22:27:41 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05: Pulling from azureml/base
# Digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#  ---> 93a72e6bd1ce
# Step 2/15 : USER root
#  ---> Running in 888899ca849f
# Removing intermediate container 888899ca849f
#  ---> f396fd8cb1a5
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 6f0874a635af
# Removing intermediate container 6f0874a635af
#  ---> b1d41b17385f
# Step 4/15 : WORKDIR /
#  ---> Running in 9715a98ad3e3
# Removing intermediate container 9715a98ad3e3
#  ---> 5ca9502911ba
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> a8b85803a1bc
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 75e631e8f13d
# Removing intermediate container 75e631e8f13d
#  ---> 3b6e97de5b05
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 4f4b98f5c08e
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_4c75fa2bcee8c368f989c66381ba5355 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in cf3790da7870
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# ca-certificates-2020 | 132 KB    |            |   0%
# ca-certificates-2020 | 132 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | ########8  |  89%
# tk-8.6.8             | 3.1 MB    | #########8 |  99%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# psutil-5.7.0         | 332 KB    |            |   0%
# psutil-5.7.0         | 332 KB    | ########## | 100%
#
# setuptools-47.1.1    | 653 KB    |            |   0%
# setuptools-47.1.1    | 653 KB    | ########6  |  86%
# setuptools-47.1.1    | 653 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #######5   |  75%
# libgcc-ng-9.1.0      | 8.1 MB    | #########7 |  98%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | #######9   |  79%
# ncurses-6.0          | 907 KB    | #########  |  90%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #######6   |  77%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #########5 |  96%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | #########  |  90%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########1  |  82%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# certifi-2020.4.5.1   | 159 KB    |            |   0%
# certifi-2020.4.5.1   | 159 KB    | ########## | 100%
#
# pip-20.0.2           | 1.9 MB    |            |   0%
# pip-20.0.2           | 1.9 MB    | #######8   |  78%
# pip-20.0.2           | 1.9 MB    | #########1 |  91%
# pip-20.0.2           | 1.9 MB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | #########3 |  93%
# readline-7.0         | 387 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | #######6   |  76%
# openssl-1.0.2u       | 3.1 MB    | #########3 |  94%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #4         |  14%
# python-3.6.2         | 27.0 MB   | ###6       |  37%
# python-3.6.2         | 27.0 MB   | ######2    |  63%
# python-3.6.2         | 27.0 MB   | #######7   |  77%
# python-3.6.2         | 27.0 MB   | ########8  |  88%
# python-3.6.2         | 27.0 MB   | #########5 |  96%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting scikit-learn
#   Downloading scikit_learn-0.23.1-cp36-cp36m-manylinux1_x86_64.whl (6.8 MB)
# Collecting azure-storage-queue~=2.1
#   Downloading azure_storage_queue-2.1.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-storage-common~=2.1
#   Downloading azure_storage_common-2.1.0-py2.py3-none-any.whl (47 kB)
# Collecting azureml-core~=1.0
#   Downloading azureml_core-1.6.0.post1-py3-none-any.whl (1.3 MB)
# Collecting azureml-telemetry~=1.0
#   Downloading azureml_telemetry-1.6.0-py3-none-any.whl (29 kB)
# Collecting filelock~=3.0
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Collecting azureml-dataprep[fuse,pandas]<1.7.0a,>=1.6.2a
#   Downloading azureml_dataprep-1.6.3-py3-none-any.whl (27.8 MB)
# Collecting numpy>=1.13.3
#   Downloading numpy-1.18.5-cp36-cp36m-manylinux1_x86_64.whl (20.1 MB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting scipy>=0.19.1
#   Downloading scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1 MB)
# Collecting joblib>=0.11
#   Downloading joblib-0.15.1-py3-none-any.whl (298 kB)
# Collecting azure-common>=1.1.5
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting cryptography
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting python-dateutil
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting requests
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.15-py2.py3-none-any.whl (84 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.4-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.3-py2.py3-none-any.whl (40 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting pytz
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-10.0.0-py2.py3-none-any.whl (809 kB)
# Collecting azure-mgmt-network~=10.0
#   Downloading azure_mgmt_network-10.2.0-py2.py3-none-any.whl (8.6 MB)
# Collecting ruamel.yaml>0.16.7
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting docker
#   Downloading docker-4.2.1-py2.py3-none-any.whl (143 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-10.0.0-py2.py3-none-any.whl (532 kB)
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting dotnetcore2>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.4.1-py3-none-any.whl (26 kB)
# Collecting azureml-dataprep-native<15.0.0,>=14.1.0
#   Downloading azureml_dataprep_native-14.2.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting pyarrow>=0.15.*; extra == "pandas"
#   Downloading pyarrow-0.17.1-cp36-cp36m-manylinux2014_x86_64.whl (63.8 MB)
# Collecting pandas>=0.23.4; extra == "pandas"
#   Downloading pandas-1.0.4-cp36-cp36m-manylinux1_x86_64.whl (10.1 MB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Collecting six>=1.4.1
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_4c75fa2bcee8c368f989c66381ba5355/lib/python3.6/site-packages (from requests->azure-storage-common~=2.1->-r /azureml-environment-setup/condaenv.io5b10_b.requirements.txt (line 3)) (2020.4.5.1)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.6.1-py2.py3-none-any.whl (31 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.3.0-py2.py3-none-any.whl (48 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.6.0-py2.py3-none-any.whl (120 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.0-py2.py3-none-any.whl (14 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=045c47d36804103762d2ea3baecc1532bc61df4c1abff9c8834af7c2a731814d
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built fusepy
# Installing collected packages: numpy, threadpoolctl, scipy, joblib, scikit-learn, azure-common, pycparser, cffi, six, cryptography, python-dateutil, urllib3, idna, chardet, requests, azure-storage-common, azure-storage-queue, pyopenssl, zipp, importlib-metadata, jsonpickle, isodate, oauthlib, requests-oauthlib, msrest, PyJWT, adal, msrestazure, azure-mgmt-authorization, contextlib2, pyasn1, ndg-httpsclient, azure-mgmt-keyvault, jmespath, azure-mgmt-containerregistry, azure-graphrbac, pytz, azure-mgmt-resource, azure-mgmt-network, ruamel.yaml.clib, ruamel.yaml, pathspec, websocket-client, docker, jeepney, SecretStorage, backports.weakref, backports.tempfile, azure-mgmt-storage, azureml-core, applicationinsights, azureml-telemetry, filelock, distro, dotnetcore2, cloudpickle, azureml-dataprep-native, msal, portalocker, msal-extensions, azure-core, azure-identity, fusepy, pyarrow, pandas, azureml-dataprep
#
# Successfully installed PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.4 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.6.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-network-10.2.0 azure-mgmt-resource-10.0.0 azure-mgmt-storage-10.0.0 azure-storage-common-2.1.0 azure-storage-queue-2.1.0 azureml-core-1.6.0.post1 azureml-dataprep-1.6.3 azureml-dataprep-native-14.2.0 azureml-telemetry-1.6.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.0 chardet-3.0.4 cloudpickle-1.4.1 contextlib2-0.6.0.post1 cryptography-2.9.2 distro-1.5.0 docker-4.2.1 dotnetcore2-2.1.14 filelock-3.0.12 fusepy-3.0.1 idna-2.9 importlib-metadata-1.6.1 isodate-0.6.0 jeepney-0.4.3 jmespath-0.10.0 joblib-0.15.1 jsonpickle-1.4.1 msal-1.3.0 msal-extensions-0.1.3 msrest-0.6.15 msrestazure-0.6.3 ndg-httpsclient-0.5.1 numpy-1.18.5 oauthlib-3.1.0 pandas-1.0.4 pathspec-0.8.0 portalocker-1.7.0 pyarrow-0.17.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 python-dateutil-2.8.1 pytz-2020.1 requests-2.23.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 scikit-learn-0.23.1 scipy-1.4.1 six-1.15.0 threadpoolctl-2.1.0 urllib3-1.25.9 websocket-client-0.57.0 zipp-3.1.0
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_4c75fa2bcee8c368f989c66381ba5355
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
# Removing intermediate container cf3790da7870
#  ---> 849daf86da99
# Step 9/15 : ENV PATH /azureml-envs/azureml_4c75fa2bcee8c368f989c66381ba5355/bin:$PATH
#  ---> Running in 2b115d663e3e
# Removing intermediate container 2b115d663e3e
#  ---> 520a5261bad1
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_4c75fa2bcee8c368f989c66381ba5355
#  ---> Running in 504e9be87a4d
# Removing intermediate container 504e9be87a4d
#  ---> 2a620dfed356
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_4c75fa2bcee8c368f989c66381ba5355/lib:$LD_LIBRARY_PATH
#  ---> Running in a4c2b0ce747c
# Removing intermediate container a4c2b0ce747c
#  ---> 350f2a73fb23
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 3375f4ea74d3
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit "--repositories" "[]" /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 1f03a4ae0803
# Removing intermediate container 1f03a4ae0803
#  ---> b78b3c87ffb3
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in a4b4323f6594
# Removing intermediate container a4b4323f6594
#  ---> 13feaade8427
# Step 15/15 : CMD ["bash"]
#  ---> Running in 033e68b69d51
# Removing intermediate container 033e68b69d51
#  ---> 593fd64b73aa
# Successfully built 593fd64b73aa
# Successfully tagged wfml470d4c29.azurecr.io/azureml/azureml_f5e49900604023d4f06a56bb2968033f:latest
# 2020/06/06 22:30:31 Successfully executed container: acb_step_0
# 2020/06/06 22:30:31 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/06/06 22:30:31 Pushing image: wfml470d4c29.azurecr.io/azureml/azureml_f5e49900604023d4f06a56bb2968033f:latest, attempt 1
# The push refers to repository [wfml470d4c29.azurecr.io/azureml/azureml_f5e49900604023d4f06a56bb2968033f]
# 0182d1427082: Preparing
# 9a7222d8cfff: Preparing
# cd6b375eb2ac: Preparing
# 2bc317eaab37: Preparing
# e1acb4bd6f93: Preparing
# bc35b1e55fb3: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# bc35b1e55fb3: Waiting
# e1acb4bd6f93: Pushed
# 0182d1427082: Pushed
# 2bc317eaab37: Pushed
# cd6b375eb2ac: Pushed
# bc35b1e55fb3: Pushed
# e1171d4d60ca: Pushed
# 6ef1a8ae63b7: Pushed
# 340dc32eb998: Pushed
# 0e259b09e5f4: Pushed
# ccdb13a20bf2: Pushed
# 9513cdf4e497: Pushed
# f2608f66a0e3: Pushed
# 85389f9ead9e: Pushed
# 7f083f9454c0: Pushed
#
# 29f36b5893dc: Pushed
# df18b66efaa6: Pushed
# 9a7222d8cfff: Pushed
# latest: digest: sha256:f1ca9a215fbcac5b93a7a84e5a7a1b5933bb7d537d95e7aadcf0239077fb08ed size: 3883
# 2020/06/06 22:32:20 Successfully pushed image: wfml470d4c29.azurecr.io/azureml/azureml_f5e49900604023d4f06a56bb2968033f:latest
# 2020/06/06 22:32:20 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 171.211325)
# 2020/06/06 22:32:20 Populating digests for step ID: acb_step_0...
# 2020/06/06 22:32:21 Successfully populated digests for step ID: acb_step_0
# 2020/06/06 22:32:21 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 108.216389)
# 2020/06/06 22:32:21 The following dependencies were found:
# 2020/06/06 22:32:21
# - image:
#     registry: wfml470d4c29.azurecr.io
#     repository: azureml/azureml_f5e49900604023d4f06a56bb2968033f
#     tag: latest
#     digest: sha256:f1ca9a215fbcac5b93a7a84e5a7a1b5933bb7d537d95e7aadcf0239077fb08ed
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#   git: {}
#
#
# Run ID: cf1 was successful after 4m47s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_bae65bea54de8e3ca74b17fbc4edb0f1ccd1fd05a30d537acee20f6a79f01a33_d.txt
# ========================================================================================================================
# 2020-06-06T22:44:30Z Starting output-watcher...
# 2020-06-06T22:44:30Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
#
# Streaming azureml-logs/55_azureml-execution-tvmps_8234af03602bd940b111018f83274471a57965a062d9df9205f5ca5d10a28761_d.txt
# ========================================================================================================================
# 2020-06-06T22:44:51Z Starting output-watcher...
# 2020-06-06T22:44:51Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 87252c12b87424140f7859f5cdb4602ee648ad8bca7157f86c4cf01b507f01b4
#
# Streaming azureml-logs/65_job_prep-tvmps_8234af03602bd940b111018f83274471a57965a062d9df9205f5ca5d10a28761_d.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-06-06T22:45:16.915723
# Starting job preparation. Current time:2020-06-06T22:45:17.501373
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 7771f637-c16a-4e47-a773-39bad37f34a5
# Starting the daemon thread to refresh tokens in background for process with pid = 86
# Starting project file download.
# Finished project file download.
# downloadDataStore - Download from datastores if requested.
# Entering context manager injector. Current time:2020-06-06T22:51:52.280104
# Acquired lockfile /tmp/681e2f9e-0a67-4731-bd6b-735c17963b3b-datastore.lock to downloading input data references
# downloadDataStore completed
# Job preparation is complete. Current time:2020-06-06T22:51:53.640825
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/06/06 22:51:56 Starting App Insight Logger for task:  runTaskLet
# Entering context manager injector. Current time:2020-06-06T22:51:58.044720
# Initialize DatasetContextManager.
# Starting the daemon thread to refresh tokens in background for process with pid = 147
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.6.0.post1 azureml-dataprep==1.6.3
# Processing 'diabetes_batch'
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "37c7b085-d024-4748-99c0-6938c7f61d83",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='wfml', subscription_id='db63e310-2279-4738-a96f-52d65ba09d6a', resource_group='learn-bcccf658-bb50-4d7b-962a-65e7bcc6af75')"
#   }
# }
# Mounted diabetes_batch to /mnt/batch/tasks/shared/LS_root/jobs/wfml/azureml/681e2f9e-0a67-4731-bd6b-735c17963b3b/mounts/workspaceblobstore/batch-data/
# Exit __enter__ of DatasetContextManager
# Entering Run History Context Manager.
# Preparing to call script [ driver/amlbi_main.py ] with arguments: ['--client_sdk_version', '1.6.0', '--scoring_module_name', 'batch_diabetes.py', '--input_format', 'None', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/wfml/azureml/681e2f9e-0a67-4731-bd6b-735c17963b3b/mounts/workspaceblobstore/azureml/681e2f9e-0a67-4731-bd6b-735c17963b3b/inferences', '--input_fds_0', 'diabetes_batch', '--input1', '/mnt/batch/tasks/shared/LS_root/jobs/wfml/azureml/681e2f9e-0a67-4731-bd6b-735c17963b3b/mounts/workspaceblobstore/batch-data/']
# After variable expansion, calling script [ driver/amlbi_main.py ] with arguments: ['--client_sdk_version', '1.6.0', '--scoring_module_name', 'batch_diabetes.py', '--input_format', 'None', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/wfml/azureml/681e2f9e-0a67-4731-bd6b-735c17963b3b/mounts/workspaceblobstore/azureml/681e2f9e-0a67-4731-bd6b-735c17963b3b/inferences', '--input_fds_0', 'diabetes_batch', '--input1', '/mnt/batch/tasks/shared/LS_root/jobs/wfml/azureml/681e2f9e-0a67-4731-bd6b-735c17963b3b/mounts/workspaceblobstore/batch-data/']
# Streaming azureml-logs/75_job_post-tvmps_8234af03602bd940b111018f83274471a57965a062d9df9205f5ca5d10a28761_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-06-06T22:53:11.623974
# Starting job release. Current time:2020-06-06T22:53:12.496514
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 535
# Entering context manager injector. Current time:2020-06-06T22:53:12.514279
# Job release is complete. Current time:2020-06-06T22:53:15.667331
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '681e2f9e-0a67-4731-bd6b-735c17963b3b', 'target': 'wfml-cluster', 'status': 'Completed', 'startTimeUtc': '2020-06-06T22:44:17.263386Z', 'endTimeUtc': '2020-06-06T22:53:41.10539Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '7771f637-c16a-4e47-a773-39bad37f34a5', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '25ea159f-93a2-43dc-bb62-58be6375b5b3', 'azureml.pipelinerunid': '4f0a0490-92fc-451e-816b-815dcc954ec8', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '37c7b085-d024-4748-99c0-6938c7f61d83'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount', 'pathOnCompute': '77290b3a-74a8-4d9b-83e8-52d7d5291687'}}], 'runDefinition': {'script': 'driver/amlbi_main.py', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.6.0', '--scoring_module_name', 'batch_diabetes.py', '--input_format', 'None', '--mini_batch_size', '$AML_PARAMETER_aml_mini_batch_size', '--error_threshold', '$AML_PARAMETER_aml_error_threshold', '--output_action', 'append_row', '--logging_level', '$AML_PARAMETER_aml_logging_level', '--run_invocation_timeout', '$AML_PARAMETER_aml_run_invocation_timeout', '--output', '$AZUREML_DATAREFERENCE_inferences', '--input_fds_0', 'diabetes_batch', '--input1', '$AZUREML_DATAREFERENCE_diabetes_batch_0'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'wfml-cluster', 'dataReferences': {'diabetes_batch_0': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'batch-data/', 'pathOnCompute': None, 'overwrite': False}, 'inferences': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/681e2f9e-0a67-4731-bd6b-735c17963b3b/inferences', 'pathOnCompute': 'diabetes/results', 'overwrite': False}}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '37c7b085-d024-4748-99c0-6938c7f61d83'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': '77290b3a-74a8-4d9b-83e8-52d7d5291687', 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'environment': {'name': 'Experiment batch_prediction_pipeline Environment', 'version': 'Autosave_2020-06-06T22:27:23Z_dd3eb6f2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['scikit-learn', 'azure-storage-queue~=2.1', 'azure-storage-common~=2.1', 'azureml-core~=1.0', 'azureml-telemetry~=1.0', 'filelock~=3.0', 'azureml-dataprep[fuse,pandas]>=1.6.2a,<1.7.0a']}, 'psutil'], 'name': 'azureml_4c75fa2bcee8c368f989c66381ba5355'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE', 'AML_PARAMETER_aml_mini_batch_size': '5', 'AML_PARAMETER_aml_error_threshold': '10', 'AML_PARAMETER_aml_logging_level': 'INFO', 'AML_PARAMETER_aml_run_invocation_timeout': '60'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'shmSize': '1g'}, 'spark': {'repositories': ['[]'], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'y ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '4f0a0490-92fc-451e-816b-815dcc954ec8', 'status': 'Completed', 'startTimeUtc': '2020-06-06T22:27:08.167329Z', 'endTimeUtc': '2020-06-06T22:53:43.296363Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{"aml_mini_batch_size":"5","aml_error_threshold":"10","aml_logging_level":"INFO","aml_run_invocation_timeout":"60","aml_node_count":"2"}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://wfml5276478113.blob.core.windows.net/azureml/ExperimentRun/dcid.4f0a0490-92fc-451e-816b-815dcc954ec8/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=YmU6x7AA8L8iVvocr9XOQoNlPd2l%2F1BnHhwltV%2Bg4Ww%3D&st=2020-06-06T22%3A43%3A46Z&se=2020-06-07T06%3A53%3A46Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://wfml5276478113.blob.core.windows.net/azureml/ExperimentRun/dcid.4f0a0490-92fc-451e-816b-815dcc954ec8/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=b%2Bvd6eoWgZ3UPO%2F1ToZgg7X0izMrj8m7Lm5ezXkreQg%3D&st=2020-06-06T22%3A43%3A46Z&se=2020-06-07T06%3A53%3A46Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://wfml5276478113.blob.core.windows.net/azureml/ExperimentRun/dcid.4f0a0490-92fc-451e-816b-815dcc954ec8/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=vhXh9Qv%2Fq%2BRhcFPdyd9pEY0Yl%2BFDwFb3LL839DrKJDk%3D&st=2020-06-06T22%3A43%3A46Z&se=2020-06-07T06%3A53%3A46Z&sp=r'}}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

shutil.rmtree('diabetes-results', ignore_errors=True)

prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')


for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#       File  Prediction
# 0    5.csv           0
# 1   50.csv           1
# 2   51.csv           0
# 3   52.csv           1
# 4   53.csv           1
# 5   63.csv           1
# 6   64.csv           1
# 7   65.csv           1
# 8   66.csv           0
# 9   67.csv           0
# 10  72.csv           1
# 11  73.csv           1
# 12  74.csv           1
# 13  75.csv           0
# 14  76.csv           1
# 15  86.csv           1
# 16  87.csv           1
# 17  88.csv           0
# 18  89.csv           1
# 19   9.csv           0

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='Diabetes_Parallel_Batch_Pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: Diabetes_Parallel_Batch_Pipeline,
# Id: 8706e613-6006-4c25-bbf9-5322ffbfccc1,
# Status: Active,
# Endpoint: https://westus.api.azureml.ms/pipelines/v1.0/subscriptions/db63e310-2279-4738-a96f-52d65ba09d6a/resourceGroups/learn-bcccf658-bb50-4d7b-962a-65e7bcc6af75/providers/Microsoft.MachineLearningServices/workspaces/wfml/PipelineRuns/PipelineSubmit/8706e613-6006-4c25-bbf9-5322ffbfccc1)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://westus.api.azureml.ms/pipelines/v1.0/subscriptions/db63e310-2279-4738-a96f-52d65ba09d6a/resourceGroups/learn-bcccf658-bb50-4d7b-962a-65e7bcc6af75/providers/Microsoft.MachineLearningServices/workspaces/wfml/PipelineRuns/PipelineSubmit/8706e613-6006-4c25-bbf9-5322ffbfccc1

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "Batch_Pipeline_via_REST"})
run_id = response.json()["Id"]
run_id
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-8470fcc9a1a5> in <module>
#       5                          headers=auth_header,
#       6                          json={"ExperimentName": "Batch_Pipeline_via_REST"})
# ----> 7 run_id = response.json()["Id"]
#       8 run_id
#
# KeyError: 'Id'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun

published_pipeline_run = PipelineRun(ws.experiments["Batch_Pipeline_via_REST"], run_id)
print('Running pipeline...')
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-18374977b82a> in <module>
#       1 from azureml.pipeline.core.run import PipelineRun
#       2
# ----> 3 published_pipeline_run = PipelineRun(ws.experiments["Batch_Pipeline_via_REST"], run_id)
#       4 print('Running pipeline...')
#       5 published_pipeline_run.wait_for_completion(show_output=True)
#
# NameError: name 'run_id' is not defined

# %% [markdown]
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

shutil.rmtree("diabetes-results", ignore_errors=True)

prediction_run = next(published_pipeline_run.get_children())
prediction_output = prediction_run.get_output_data("inferences")
prediction_output.download(local_path="diabetes-results")


for root, dirs, files in os.walk("diabetes-results"):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-bbf9c1a3bf3e> in <module>
#       4 shutil.rmtree("diabetes-results", ignore_errors=True)
#       5
# ----> 6 prediction_run = next(published_pipeline_run.get_children())
#       7 prediction_output = prediction_run.get_output_data("inferences")
#       8 prediction_output.download(local_path="diabetes-results")
#
# NameError: name 'published_pipeline_run' is not defined

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
