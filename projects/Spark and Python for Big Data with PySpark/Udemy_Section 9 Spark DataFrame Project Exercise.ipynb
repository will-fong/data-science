# %% [markdown]
# # Spark DataFrames Project Exercise

# %% [markdown]
# Let's get some quick practice with your new Spark DataFrame skills, you will be asked some basic questions about some stock market data, in this case Walmart Stock from the years 2012-2017. This exercise will just ask a bunch of questions, unlike the future machine learning exercises, which will be a little looser and be in the form of "Consulting Projects", but more on that later!
#
# For now, just answer the questions and complete the tasks below.

# %% [markdown]
# #### Use the walmart_stock.csv file to Answer and complete the  tasks below!

# %% [markdown]
# #### Start a simple Spark Session

# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.appName('Project').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Load the Walmart Stock CSV File, have Spark infer the data types.

# %%
df = sqlContext.sql('SELECT * FROM walmart_stock_csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### What are the column names?

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [&#39;Date&#39;, &#39;Open&#39;, &#39;High&#39;, &#39;Low&#39;, &#39;Close&#39;, &#39;Volume&#39;, &#39;Adj Close&#39;]</div>

# %% [markdown]
# #### What does the Schema look like?

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Date: string (nullable = true)
# -- Open: double (nullable = true)
# -- High: double (nullable = true)
# -- Low: double (nullable = true)
# -- Close: double (nullable = true)
# -- Volume: integer (nullable = true)
# -- Adj Close: double (nullable = true)
#
# </div>

# %% [markdown]
# #### Print out the first 5 columns.

# %%
df.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [Row(Date=&#39;2012-01-03&#39;, Open=59.970001, High=61.060001, Low=59.869999, Close=60.330002, Volume=12668800, Adj Close=52.619234999999996),
#  Row(Date=&#39;2012-01-04&#39;, Open=60.209998999999996, High=60.349998, Low=59.470001, Close=59.709998999999996, Volume=9593300, Adj Close=52.078475),
#  Row(Date=&#39;2012-01-05&#39;, Open=59.349998, High=59.619999, Low=58.369999, Close=59.419998, Volume=12768200, Adj Close=51.825539),
#  Row(Date=&#39;2012-01-06&#39;, Open=59.419998, High=59.450001, Low=58.869999, Close=59.0, Volume=8069400, Adj Close=51.45922),
# ...

# %% [markdown]
# #### Use describe() to learn about the DataFrame.

# %%
df.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# summary|      Date|              Open|             High|              Low|            Close|           Volume|        Adj Close|
# +-------+----------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+
#   count|      1258|              1258|             1258|             1258|             1258|             1258|             1258|
# ...

# %% [markdown]
# ## Bonus Question!
# #### There are too many decimal places for mean and stddev in the describe() dataframe. Format the numbers to just show up to two decimal places. Pay careful attention to the datatypes that .describe() returns, we didn't cover how to do this exact formatting, but we covered something very similar. [Check this link for a hint](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.Column.cast)
#
# If you get stuck on this, don't worry, just view the solutions.

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Date: string (nullable = true)
# -- Open: double (nullable = true)
# -- High: double (nullable = true)
# -- Low: double (nullable = true)
# -- Close: double (nullable = true)
# -- Volume: integer (nullable = true)
# -- Adj Close: double (nullable = true)
#
# </div>

# %%
from pyspark.sql.types import DoubleType
from pyspark.sql.functions import round, col

cols = ['Open'
        ,'High'
        ,'Low'
        ,'Close'
        ,'Adj Close'
       ]

for col_name in cols:
    df_staging = df.withColumn(col_name, round(col(col_name).cast('float'),2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_staging.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------------------+------------------+------------------+------------------+--------+---------+
#       Date|              Open|              High|               Low|             Close|  Volume|Adj Close|
# +----------+------------------+------------------+------------------+------------------+--------+---------+
# 2012-01-03|         59.970001|         61.060001|         59.869999|         60.330002|12668800|    52.62|
# 2012-01-04|60.209998999999996|         60.349998|         59.470001|59.709998999999996| 9593300|    52.08|
# ...

# %% [markdown]
# #### Create a new dataframe with a column called HV Ratio that is the ratio of the High Price versus volume of stock traded for a day.

# %%
df_analysis = df_staging.withColumn('HV Ratio',df['High']/df['Volume'])
df_analysis.select('HV Ratio').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#             HV Ratio|
# +--------------------+
# 4.819714653321546E-6|
# 6.290848613094555E-6|
# 4.669412994783916E-6|
# 7.367338463826307E-6|
# 8.915604778943901E-6|
# 8.644477436914568E-6|
# 9.351828421515645E-6|
#  8.29141562102703E-6|
# 7.712212102001476E-6|
# 7.071764823529412E-6|
# 1.015495466386981E-5|
# 6.576354146362592...|
#  5.90145296180676E-6|
# 8.547679455011844E-6|
# 8.420709512685392E-6|
# 1.041448341728929...|
# 8.316075414862431E-6|
# 9.721183814992126E-6|
# 8.029436027707578E-6|
# 6.307432259386365E-6|
# +--------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# #### What day had the Peak High in Price?

# %%
df_staging.groupby().max('High').collect()[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: Row(max(High)=90.970001)</div>

# %% [markdown]
# #### What is the mean of the Close column?

# %%
df_staging.groupby().mean('Close').collect()[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: Row(avg(Close)=72.38844998012726)</div>

# %% [markdown]
# #### What is the max and min of the Volume column?

# %%
df_staging.groupby().min('Volume').collect()[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: Row(min(Volume)=2094900)</div>

# %%
df_staging.groupby().max('Volume').collect()[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: Row(max(Volume)=80898100)</div>

# %% [markdown]
# #### How many days was the Close lower than 60 dollars?

# %%
df_staging.filter(df.Close < 60).groupby().count().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [Row(count=81)]</div>

# %% [markdown]
# #### What percentage of the time was the High greater than 80 dollars ?
# #### In other words, (Number of Days High>80)/(Total Days in the dataset)

# %%
countDaysHigh = df_staging.filter(df.High > 80).groupby().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
countDays = df_staging.groupby().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pctDaysHigh = countDaysHigh.collect()[0][0]/countDays.collect()[0][0]
pctDaysHigh = pctDaysHigh * 100
pctDaysHigh
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: 9.141494435612083</div>

# %% [markdown]
# #### What is the Pearson correlation between High and Volume?
# #### [Hint](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrameStatFunctions.corr)

# %%
from pyspark.sql.functions import corr

corr = corr('High', 'Volume')
corr
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: Column&lt;b&#39;corr(High, Volume)&#39;&gt;</div>

# %% [markdown]
# #### What is the max High per year?

# %%
from pyspark.sql.functions import year

maxHighYear = df_staging.groupby(year('Date')).max().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
maxHighYear
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: [Row(year(Date)=2015, max(Open)=90.800003, max(High)=90.970001, max(Low)=89.25, max(Close)=90.470001, max(Volume)=80898100, max(Adj Close)=84.91000366210938),
#  Row(year(Date)=2013, max(Open)=81.209999, max(High)=81.370003, max(Low)=80.82, max(Close)=81.209999, max(Volume)=25683700, max(Adj Close)=73.93000030517578),
#  Row(year(Date)=2014, max(Open)=87.08000200000001, max(High)=88.089996, max(Low)=86.480003, max(Close)=87.540001, max(Volume)=22812400, max(Adj Close)=81.70999908447266),
# ...

# %% [markdown]
# #### What is the average Close for each Calendar Month?
# #### In other words, across all the years, what is the average Close price for Jan,Feb, Mar, etc... Your result will have a value for each of these months.

# %%
from pyspark.sql.functions import month

avgCloseMonth = df_staging.groupby(month('Date')).avg().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
avgCloseMonth
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: [Row(month(Date)=12, avg(Open)=72.87952850943395, avg(High)=73.35566025471698, avg(Low)=72.44481152830188, avg(Close)=72.84792478301885, avg(Volume)=7967959.433962264, avg(Adj Close)=68.4600944519043),
#  Row(month(Date)=1, avg(Open)=71.40811884158416, avg(High)=71.97009924752473, avg(Low)=70.90425712871289, avg(Close)=71.44801958415842, avg(Volume)=8761851.485148516, avg(Adj Close)=65.56851502220229),
#  Row(month(Date)=6, avg(Open)=72.5100938962264, avg(High)=72.9262265471698, avg(Low)=72.12198099056603, avg(Close)=72.4953774245283, avg(Volume)=8303756.603773585, avg(Adj Close)=67.43820755436735),
# ...

# %% [markdown]
# # Great Job!
