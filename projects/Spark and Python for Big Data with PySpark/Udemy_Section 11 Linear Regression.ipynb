# %% [markdown]
# # 36. Linear Regression Documentation

# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.appName('lr').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.regression import LinearRegression
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training = spark.read.format('libsvm').load('/FileStore/tables/sample_linear_regression_data.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+--------------------+
#               label|            features|
# +-------------------+--------------------+
#  -9.490009878824548|(10,[0,1,2,3,4,5,...|
#  0.2577820163584905|(10,[0,1,2,3,4,5,...|
#  -4.438869807456516|(10,[0,1,2,3,4,5,...|
# -19.782762789614537|(10,[0,1,2,3,4,5,...|
#  -7.966593841555266|(10,[0,1,2,3,4,5,...|
#  -7.896274316726144|(10,[0,1,2,3,4,5,...|
#  -8.464803554195287|(10,[0,1,2,3,4,5,...|
#  2.1214592666251364|(10,[0,1,2,3,4,5,...|
#  1.0720117616524107|(10,[0,1,2,3,4,5,...|
# -13.772441561702871|(10,[0,1,2,3,4,5,...|
#  -5.082010756207233|(10,[0,1,2,3,4,5,...|
#   7.887786536531237|(10,[0,1,2,3,4,5,...|
#  14.323146365332388|(10,[0,1,2,3,4,5,...|
# -20.057482615789212|(10,[0,1,2,3,4,5,...|
# -0.8995693247765151|(10,[0,1,2,3,4,5,...|
#  -19.16829262296376|(10,[0,1,2,3,4,5,...|
#   5.601801561245534|(10,[0,1,2,3,4,5,...|
# -3.2256352187273354|(10,[0,1,2,3,4,5,...|
#  1.5299675726687754|(10,[0,1,2,3,4,5,...|
#  -0.250102447941961|(10,[0,1,2,3,4,5,...|
# +-------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
lr = LinearRegression(featuresCol='features'
                      ,labelCol='label'
                      ,predictionCol='prediction'
                     )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lrModel = lr.fit(training)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lrModel.coefficients
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: DenseVector([0.0073, 0.8314, -0.8095, 2.4412, 0.5192, 1.1535, -0.2989, -0.5129, -0.6197, 0.6956])</div>

# %%
lrModel.intercept
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: 0.14228558260358093</div>

# %%
training_summary = lrModel.summary
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training_summary.r2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: 0.027839179518600154</div>

# %%
training_summary.rootMeanSquaredError
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 10.16309157133015</div>

# %%
data_all = spark.read.format('libsvm').load('/FileStore/tables/sample_linear_regression_data.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_split = data_all.randomSplit([0.7,0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_split
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [DataFrame[label: double, features: vector],
#  DataFrame[label: double, features: vector]]</div>

# %%
train_data, test_data = data_all.randomSplit([0.7,0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+
# summary|              label|
# +-------+-------------------+
#   count|                352|
#    mean| 0.2238957224996593|
#  stddev|  10.02853413926738|
#     min|-28.571478869743427|
#     max|  27.78383192005107|
# +-------+-------------------+
#
# </div>

# %%
train_model = lr.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_results = train_model.evaluate(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_results.rootMeanSquaredError
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 11.041058349224617</div>

# %%
data_unlabeled = test_data.select('features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_unlabeled.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#             features|
# +--------------------+
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# (10,[0,1,2,3,4,5,...|
# +--------------------+
# only showing top 20 rows
#
# </div>

# %%
predictions = train_model.transform(data_unlabeled)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+
#             features|          prediction|
# +--------------------+--------------------+
# (10,[0,1,2,3,4,5,...| -0.2748160120973333|
# (10,[0,1,2,3,4,5,...|  1.1932963263266254|
# (10,[0,1,2,3,4,5,...| -1.8491347643318843|
# (10,[0,1,2,3,4,5,...|  0.9575873600021145|
# (10,[0,1,2,3,4,5,...|   1.600822275360307|
# (10,[0,1,2,3,4,5,...|  -0.438272694328646|
# (10,[0,1,2,3,4,5,...|  0.3090039988144056|
# (10,[0,1,2,3,4,5,...|  0.2174762781151981|
# (10,[0,1,2,3,4,5,...| -1.1773694725626096|
# (10,[0,1,2,3,4,5,...|   1.361438805823599|
# (10,[0,1,2,3,4,5,...|-0.24797655085710207|
# (10,[0,1,2,3,4,5,...|  2.6324776803038676|
# (10,[0,1,2,3,4,5,...|   2.026459979779556|
# (10,[0,1,2,3,4,5,...|   4.085822115385382|
# (10,[0,1,2,3,4,5,...| -0.5867149001630209|
# (10,[0,1,2,3,4,5,...|  -2.175458327493602|
# (10,[0,1,2,3,4,5,...| -1.7759989468963455|
# (10,[0,1,2,3,4,5,...| -3.0647859927654486|
# (10,[0,1,2,3,4,5,...| -1.0926443888150261|
# (10,[0,1,2,3,4,5,...|  -2.824672645519052|
# +--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# # 38. Linear Regression Example Code Along

# %%
spark = SparkSession.builder.appName('lr_example').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data = spark.read.csv('/FileStore/tables/Ecommerce_Customers.csv',inferSchema=True,header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Email: string (nullable = true)
# -- Address: string (nullable = true)
# -- Avatar: string (nullable = true)
# -- Avg Session Length: double (nullable = true)
# -- Time on App: double (nullable = true)
# -- Time on Website: double (nullable = true)
# -- Length of Membership: double (nullable = true)
# -- Yearly Amount Spent: double (nullable = true)
#
# </div>

# %%
for item in data.head(1)[0]:
  print(item)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">mstephenson@fernandez.com
# 835 Frank TunnelWrightmouth, MI 82180-9605
# Violet
# 34.49726772511229
# 12.65565114916675
# 39.57766801952616
# 4.0826206329529615
# 587.9510539684005
# </div>

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: [&#39;Email&#39;,
#  &#39;Address&#39;,
#  &#39;Avatar&#39;,
#  &#39;Avg Session Length&#39;,
#  &#39;Time on App&#39;,
#  &#39;Time on Website&#39;,
#  &#39;Length of Membership&#39;,
#  &#39;Yearly Amount Spent&#39;]</div>

# %%
assembler = VectorAssembler(inputCols=['Avg Session Length'
                                       ,'Time on App'
                                       , 'Time on Website'
                                       , 'Length of Membership']
                           ,outputCol='features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output = assembler.transform(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Email: string (nullable = true)
# -- Address: string (nullable = true)
# -- Avatar: string (nullable = true)
# -- Avg Session Length: double (nullable = true)
# -- Time on App: double (nullable = true)
# -- Time on Website: double (nullable = true)
# -- Length of Membership: double (nullable = true)
# -- Yearly Amount Spent: double (nullable = true)
# -- features: vector (nullable = true)
#
# </div>

# %%
output.head(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: [Row(Email=&#39;mstephenson@fernandez.com&#39;, Address=&#39;835 Frank TunnelWrightmouth, MI 82180-9605&#39;, Avatar=&#39;Violet&#39;, Avg Session Length=34.49726772511229, Time on App=12.65565114916675, Time on Website=39.57766801952616, Length of Membership=4.0826206329529615, Yearly Amount Spent=587.9510539684005, features=DenseVector([34.4973, 12.6557, 39.5777, 4.0826]))]</div>

# %%
data_final = output.select('features','Yearly Amount Spent')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_data, test_data = data_final.randomSplit([0.7,0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+
# summary|Yearly Amount Spent|
# +-------+-------------------+
#   count|                351|
#    mean| 498.28229133018056|
#  stddev|  78.64922912233413|
#     min| 256.67058229005585|
#     max|  725.5848140556806|
# +-------+-------------------+
#
# </div>

# %%
test_data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+
# summary|Yearly Amount Spent|
# +-------+-------------------+
#   count|                149|
#    mean| 501.74452934497924|
#  stddev|  81.07709007448481|
#     min|   266.086340948469|
#     max|  765.5184619388373|
# +-------+-------------------+
#
# </div>

# %%
lr = LinearRegression(labelCol='Yearly Amount Spent')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lr_model = lr.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_results = lr_model.evaluate(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_results.residuals.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#            residuals|
# +--------------------+
#  -11.813913440281908|
#   -5.218178077078903|
# -0.27509519824531026|
#   10.074621666328198|
#  -16.659241998177663|
#  -0.8733967615102074|
#   -4.522880868895754|
#   2.5099397324285064|
#   3.5426185847740044|
#   -4.423958633773509|
#   -5.049546907327567|
#  -15.039126810368089|
#  -2.5382708821817914|
#  -1.6300257718884836|
#   1.4683109772075227|
#   -4.716175364290223|
#  -12.162592468600451|
#    -2.89417449175761|
#   -9.337127266995537|
#    1.015016757879721|
# +--------------------+
# only showing top 20 rows
#
# </div>

# %%
test_results.rootMeanSquaredError
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: 9.484044506573701</div>

# %%
test_results.r2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: 0.9862242448977014</div>

# %%
data_final.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+
# summary|Yearly Amount Spent|
# +-------+-------------------+
#   count|                500|
#    mean|  499.3140382585909|
#  stddev|   79.3147815497068|
#     min| 256.67058229005585|
#     max|  765.5184619388373|
# +-------+-------------------+
#
# </div>

# %%
data_unlabeled = test_data.select('features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = lr_model.transform(data_unlabeled)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------------------+
#             features|        prediction|
# +--------------------+------------------+
# [30.3931845423455...| 331.7427832434755|
# [30.4925366965402...| 287.6894237969934|
# [30.5743636841713...|442.33950895631097|
# [30.7377203726281...| 451.7061205299017|
# [30.8162006488763...|282.74558294664666|
# [31.2606468698795...| 422.2000280184616|
# [31.2681042107507...| 427.9934140427197|
# [31.3091926408918...| 430.2107781075051|
# [31.3662121671876...| 427.0462639717109|
# [31.4252268808548...| 535.1906772885354|
# [31.5147378578019...|  494.862034903789|
# [31.5741380228732...| 559.4483989709549|
# [31.5761319713222...| 543.7648548715101|
# [31.7216523605090...| 349.4069524037611|
# [31.7366356860502...| 495.4651352783244|
# [31.7656188210424...|501.27025699989736|
# [31.8093003166791...| 548.9344918314416|
# [31.8186165667690...|449.31284786189326|
# [31.8279790554652...|449.33987481393706|
# [31.8293464559211...|384.13732123009527|
# +--------------------+------------------+
# only showing top 20 rows
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
